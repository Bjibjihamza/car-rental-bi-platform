# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

DATA_DIR = "data"  # adapte selon ton arborescence

# %%
def load_all_telemetry(data_dir=DATA_DIR):
    files = sorted(glob.glob(os.path.join(data_dir, "iot_telemetry_*.csv")))
    if not files:
        raise FileNotFoundError("Aucun fichier CSV trouvé dans data/. Génère la télémétrie d'abord.")
    
    dfs = []
    for f in files:
        df = pd.read_csv(f, parse_dates=["TIMESTAMP"])
        df["SOURCE_FILE"] = os.path.basename(f)
        dfs.append(df)

    full_df = pd.concat(dfs, ignore_index=True)
    print(f"📦 {len(files)} fichiers chargés, {len(full_df):,} lignes au total")
    return full_df

df = load_all_telemetry()
df.head()
# Out:
# 📦 7 fichiers chargés, 27,404 lignes au total
#    DEVICE_ID  CAR_ID  RENTAL_ID           TIMESTAMP   LATITUDE  LONGITUDE  \
# 0        117      17          1 2025-12-10 11:26:00  34.020900  -6.841600
# 1        117      17          1 2025-12-10 11:26:30  34.018442  -6.838634
# 2        107       7          1 2025-12-10 11:27:00  33.573100  -7.589800
# 3        117      17          1 2025-12-10 11:27:00  34.015984  -6.835668
# 4        107       7          1 2025-12-10 11:27:30  33.574831  -7.588747
#
#    SPEED_KMH  ACCELERATION_MS2  BRAKE_PRESSURE_BAR  FUEL_LEVEL_PCT  \
# 0   0.000000          0.000000            0.000000      100.000000
# 1   9.907915          0.000000            1.540038       99.988991
# 2   0.000000          0.000000            0.000000      100.000000
# 3  13.988296          0.037781            0.647140       99.973449
# 4   5.949430          0.000000            4.198312       99.992754
#
#    BATTERY_VOLTAGE  ENGINE_TEMP_C   ODOMETER_KM    EVENT_TYPE    BRANCH_NAME  \
# 0        12.682173      42.832691   8000.000000  ENGINE_START    Rabat Agdal
# 1        14.004367      44.866627   8000.082566       DRIVING    Rabat Agdal
# 2        12.376352      42.539768  37000.000000  ENGINE_START  Casablanca HQ
# 3        14.079805      46.943758   8000.199135       DRIVING    Rabat Agdal
# 4        13.999232      44.758974  37000.049579       DRIVING  Casablanca HQ
#
#          CITY           CREATED_AT                 SOURCE_FILE
# 0       Rabat  2025-12-10 11:26:00  iot_telemetry_20251210.csv
# 1       Rabat  2025-12-10 11:26:30  iot_telemetry_20251210.csv
# 2  Casablanca  2025-12-10 11:27:00  iot_telemetry_20251210.csv
# 3       Rabat  2025-12-10 11:27:00  iot_telemetry_20251210.csv
# 4  Casablanca  2025-12-10 11:27:30  iot_telemetry_20251210.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27404 entries, 0 to 27403
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DEVICE_ID           27404 non-null  int64
#  1   CAR_ID              27404 non-null  int64
#  2   RENTAL_ID           27404 non-null  int64
#  3   TIMESTAMP           27404 non-null  datetime64[ns]
#  4   LATITUDE            27404 non-null  float64
#  5   LONGITUDE           27404 non-null  float64
#  6   SPEED_KMH           27404 non-null  float64
#  7   ACCELERATION_MS2    27404 non-null  float64
#  8   BRAKE_PRESSURE_BAR  27404 non-null  float64
#  9   FUEL_LEVEL_PCT      27404 non-null  float64
#  10  BATTERY_VOLTAGE     27404 non-null  float64
#  11  ENGINE_TEMP_C       27404 non-null  float64
#  12  ODOMETER_KM         27404 non-null  float64
#  13  EVENT_TYPE          27404 non-null  object
#  14  BRANCH_NAME         27404 non-null  object
#  15  CITY                27404 non-null  object
#  16  CREATED_AT          27404 non-null  object
#  17  SOURCE_FILE         27404 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(3), object(5)
# memory usage: 3.8+ MB

# %%
df["EVENT_TYPE"].value_counts()
# Out:
# EVENT_TYPE
# DRIVING         26725
# ENGINE_START      257
# ENGINE_STOP       257
# IDLE              164
# REFUEL              1
# Name: count, dtype: int64

# %%
car_id = df["CAR_ID"].iloc[0]  # choisit la première voiture automatiquement
car_df = df[df["CAR_ID"] == car_id].sort_values("TIMESTAMP")

print(f"🚗 CAR_ID = {car_id}, {len(car_df)} lignes")
car_df.head()
# Out:
# 🚗 CAR_ID = 17, 930 lignes
#    DEVICE_ID  CAR_ID  RENTAL_ID           TIMESTAMP   LATITUDE  LONGITUDE  \
# 0        117      17          1 2025-12-10 11:26:00  34.020900  -6.841600
# 1        117      17          1 2025-12-10 11:26:30  34.018442  -6.838634
# 3        117      17          1 2025-12-10 11:27:00  34.015984  -6.835668
# 5        117      17          1 2025-12-10 11:27:30  34.013525  -6.832702
# 7        117      17          1 2025-12-10 11:28:00  34.011067  -6.829737
#
#    SPEED_KMH  ACCELERATION_MS2  BRAKE_PRESSURE_BAR  FUEL_LEVEL_PCT  \
# 0   0.000000          0.000000            0.000000      100.000000
# 1   9.907915          0.000000            1.540038       99.988991
# 3  13.988296          0.037781            0.647140       99.973449
# 5  26.696135          0.117665            4.320488       99.943786
# 7  20.614337         -0.056313            1.047280       99.920881
#
#    BATTERY_VOLTAGE  ENGINE_TEMP_C  ODOMETER_KM    EVENT_TYPE  BRANCH_NAME  \
# 0        12.682173      42.832691  8000.000000  ENGINE_START  Rabat Agdal
# 1        14.004367      44.866627  8000.082566       DRIVING  Rabat Agdal
# 3        14.079805      46.943758  8000.199135       DRIVING  Rabat Agdal
# 5        14.276345      50.988517  8000.421603       DRIVING  Rabat Agdal
# 7        13.686751      54.542067  8000.593389       DRIVING  Rabat Agdal
#
#     CITY           CREATED_AT                 SOURCE_FILE
# 0  Rabat  2025-12-10 11:26:00  iot_telemetry_20251210.csv
# 1  Rabat  2025-12-10 11:26:30  iot_telemetry_20251210.csv
# 3  Rabat  2025-12-10 11:27:00  iot_telemetry_20251210.csv
# 5  Rabat  2025-12-10 11:27:30  iot_telemetry_20251210.csv
# 7  Rabat  2025-12-10 11:28:00  iot_telemetry_20251210.csv

# %%
import numpy as np
from IPython.display import display

def check_start_stop(df, tolerance=0.0005):
    """
    tolerance = tolérance en latitude/longitude (environ ~50 m)
    """
    results = []
    cars = df["CAR_ID"].unique()

    for car in cars:
        car_df = df[df["CAR_ID"] == car].sort_values("TIMESTAMP")
        starts = car_df[car_df["EVENT_TYPE"] == "ENGINE_START"]
        stops  = car_df[car_df["EVENT_TYPE"] == "ENGINE_STOP"]

        # Assure même nombre de start/stop (sinon anomalie)
        n = min(len(starts), len(stops))

        for i in range(n):
            s = starts.iloc[i]
            e = stops.iloc[i]

            lat_diff = abs(s["LATITUDE"]  - e["LATITUDE"])
            lon_diff = abs(s["LONGITUDE"] - e["LONGITUDE"])

            ok = lat_diff < tolerance and lon_diff < tolerance

            results.append({
                "CAR_ID": car,
                "TRIP_INDEX": i + 1,
                "START_TIME": s["TIMESTAMP"],
                "STOP_TIME": e["TIMESTAMP"],
                "START_LAT": s["LATITUDE"],
                "START_LON": s["LONGITUDE"],
                "STOP_LAT": e["LATITUDE"],
                "STOP_LON": e["LONGITUDE"],
                "LAT_DIFF": lat_diff,
                "LON_DIFF": lon_diff,
                "MATCH": ok
            })

    return pd.DataFrame(results)


# 🔍 Appliquer le contrôle
check_df = check_start_stop(df)

print("🚦 Vérification Start=Stop pour toutes les voitures :")
display(check_df)

# Afficher uniquement anomalies
anomalies = check_df[check_df["MATCH"] == False]

if len(anomalies) == 0:
    print("✅ Toutes les voitures reviennent bien à leur position initiale.")
else:
    print("❌ Anomalies détectées :")
    display(anomalies)
# Out:
# 🚦 Vérification Start=Stop pour toutes les voitures :
#      CAR_ID  TRIP_INDEX          START_TIME           STOP_TIME  START_LAT  \
# 0        17           1 2025-12-10 11:26:00 2025-12-10 12:26:00    34.0209
# 1        17           2 2025-12-10 16:14:00 2025-12-10 17:37:00    34.0209
# 2        17           3 2025-12-11 14:06:00 2025-12-11 15:26:00    34.0209
# 3        17           4 2025-12-13 11:37:00 2025-12-13 12:59:00    34.0209
# 4        17           5 2025-12-13 16:08:00 2025-12-13 17:20:00    34.0209
# ..      ...         ...                 ...                 ...        ...
# 252      43           1 2025-12-14 14:06:00 2025-12-14 14:36:00    35.7595
# 253      43           2 2025-12-16 11:41:00 2025-12-16 13:09:00    35.7595
# 254      43           3 2025-12-16 16:12:00 2025-12-16 16:54:00    35.7595
# 255      12           1 2025-12-14 14:15:00 2025-12-14 14:50:00    33.5731
# 256      12           2 2025-12-15 14:09:00 2025-12-15 15:24:00    33.5731
#
#      START_LON  STOP_LAT  STOP_LON  LAT_DIFF  LON_DIFF  MATCH
# 0      -6.8416   34.0209   -6.8416       0.0       0.0   True
# 1      -6.8416   34.0209   -6.8416       0.0       0.0   True
# 2      -6.8416   34.0209   -6.8416       0.0       0.0   True
# 3      -6.8416   34.0209   -6.8416       0.0       0.0   True
# 4      -6.8416   34.0209   -6.8416       0.0       0.0   True
# ..         ...       ...       ...       ...       ...    ...
# 252    -5.8340   35.7595   -5.8340       0.0       0.0   True
# 253    -5.8340   35.7595   -5.8340       0.0       0.0   True
# 254    -5.8340   35.7595   -5.8340       0.0       0.0   True
# 255    -7.5898   33.5731   -7.5898       0.0       0.0   True
# 256    -7.5898   33.5731   -7.5898       0.0       0.0   True
#
# [257 rows x 11 columns]
# ✅ Toutes les voitures reviennent bien à leur position initiale.

# %%
import pandas as pd

# 1) Vérifier qu'on a folium
try:
    import folium
    from folium.plugins import AntPath
except ImportError as e:
    print("❌ Le module 'folium' n'est pas installé.")
    print("➡ Installe-le d'abord avec :  !pip install folium")
    raise e

# 2) Vérifier que df existe
try:
    df
except NameError:
    raise NameError(
        "❌ Le DataFrame 'df' n'existe pas. "
        "Charge d'abord tes CSV dans df (ex: df = load_all_telemetry())."
    )

# 3) Vérifier les colonnes nécessaires
required_cols = {"CAR_ID", "LATITUDE", "LONGITUDE", "TIMESTAMP", "EVENT_TYPE"}
missing = required_cols - set(df.columns)
if missing:
    print("Colonnes présentes :", list(df.columns))
    raise KeyError(f"❌ Colonnes manquantes dans df : {missing}")

# 4) Nettoyage de base
telemetry = df.dropna(subset=["LATITUDE", "LONGITUDE"]).copy()
telemetry = telemetry.sort_values("TIMESTAMP")

if telemetry.empty:
    raise ValueError("❌ Aucun point avec LATITUDE/LONGITUDE non nuls dans df.")

# 5) Choisir automatiquement une voiture qui a des points GPS
cars_counts = telemetry.groupby("CAR_ID").size().sort_values(ascending=False)
car_id = int(cars_counts.index[0])  # voiture avec le plus de points
print(f"🚗 CAR_ID sélectionné automatiquement : {car_id} ({cars_counts.iloc[2]} points)")

car_df = telemetry[telemetry["CAR_ID"] == car_id].copy()

# (Optionnel) filtrer sur 1 jour pour plus de lisibilité
# décommenter et adapte DATE_TARGET si tu veux :
# DATE_TARGET = pd.to_datetime("2025-12-10").date()
# car_df = car_df[car_df["TIMESTAMP"].dt.date == DATE_TARGET]

if car_df.empty:
    raise ValueError("❌ car_df est vide après filtrage. Vérifie le filtre de date éventuellement.")

print(f"📊 Nombre de points pour CAR_ID={car_id}: {len(car_df)}")

# 6) Préparation des points GPS
points = list(zip(car_df["LATITUDE"], car_df["LONGITUDE"]))

# Centre de la carte
center_lat = car_df["LATITUDE"].mean()
center_lon = car_df["LONGITUDE"].mean()

# 7) Création de la carte
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Trajet continu
folium.PolyLine(
    locations=points,
    weight=4,
    opacity=0.8,
).add_to(m)

# Variante animée (ligne "vivante")
AntPath(
    locations=points,
    dash_array=[10, 20],
    delay=800,
).add_to(m)

# 8) Marqueurs START/STOP

start_point = car_df.iloc[0]
end_point   = car_df.iloc[-1]

folium.Marker(
    location=[start_point["LATITUDE"], start_point["LONGITUDE"]],
    popup=f"START<br>{start_point['TIMESTAMP']}",
    icon=folium.Icon(color="green", icon="play")
).add_to(m)

folium.Marker(
    location=[end_point["LATITUDE"], end_point["LONGITUDE"]],
    popup=f"STOP<br>{end_point['TIMESTAMP']}",
    icon=folium.Icon(color="red", icon="stop")
).add_to(m)

print("✅ Carte générée. Si tu es dans un notebook, la carte doit s'afficher juste en dessous 👇")

m
# Out:
# 🚗 CAR_ID sélectionné automatiquement : 10 (1000 points)
# 📊 Nombre de points pour CAR_ID=10: 1000
# ✅ Carte générée. Si tu es dans un notebook, la carte doit s'afficher juste en dessous 👇
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_804372eef3057028436af675898024bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_804372eef3057028436af675898024bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_804372eef3057028436af675898024bd = L.map(
#                 &quot;map_804372eef3057028436af675898024bd&quot;,
#                 {
#                     center: [33.540839578645894, -7.482011650485316],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a12f4c5c80202ec00ec001a5e4b483a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6